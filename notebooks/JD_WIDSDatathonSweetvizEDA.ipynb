# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sweetviz
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv("TrainingWiDS2021.csv")
test = pd.read_csv("UnlabeledWiDS2021.csv")

# %%
my_report = sweetviz.compare([train, "Train"], [test, "Test"], "diabetes_mellitus")

# %%
my_report.show_html("Report.html") #Not providing a filename will default to SEETVIZ_REPORT.html
# Out:
# Report Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Notes from SweetViz EDA
#
# ![image.png](attachment:image.png)
# Dataset is imbalanced for label.  Will need to use methods to deal with this.

# %% [markdown]
# ## Identifiers
# Unnamed - Related to icu_id.  Test version has completely different version than train dataset. DROP
# encounter_id - main id.  Relatively even distribution in train, but not in test.
# hospital_id - Look for pattern in distributions in their respective ranges for train and test.
#
# ## Categorical
# icu_id - Highly correlated to Unnamed.  Train and Test sets seem to be using same system. This feature is categorical and should be changed
#
# ## Standouts
# Age - There are more people over 80 in the test set
#
# ![image.png](attachment:image.png)

# %% [markdown]
# BMI - There are a bit more people with BMI in 30 range in the test set
# ![image.png](attachment:image.png)

# %% [markdown]
# There are more peopole with elective_surgery in Test datset
# ![image.png](attachment:image.png)

# %% [markdown]
# icu_ids shows disparity between the tranin and test datasets...
# ![image.png](attachment:image.png)

# %% [markdown]
# fio2_apache - The test set has a good chunk more patients with the highest score This feature has missing data 77% and 75% respectively train and test.  Candidate for drop.
# ![image.png](attachment:image.png)
